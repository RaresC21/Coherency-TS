# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from matplotlib import pyplot as plt
import random
import os

import torch
import torch.nn as nn
import torch.nn.functional as F

from utils import *

from models import * 
import torch.optim as optim

from sklearn import preprocessing

from Experiments import *

seed = 0 

def set_seeds(seed): 
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 

set_seeds(seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# %load_ext autoreload
# %autoreload 2
# Out:
# cuda

# %%
# dataset = "traffic"
# data_file = "traffic_data/data.csv"
# hier_file = "traffic_data/agg_mat.csv"
# data = pd.read_csv(data_file, index_col=0)
# agg_mat_df = pd.read_csv(hier_file, index_col=0)

dataset = 'labor'
data_file = "labor/data.csv"
hier_file = "labor/agg_mat.csv"

data = pd.read_csv(data_file, index_col=0)
agg_mat_df = pd.read_csv(hier_file, index_col=0)
base_agg_mat = agg_mat_df.values

# %%
maximum = np.max(data.values)
data = (data / maximum).values

# %%
batch_size = 32
context_window = 5
train_split = 0.8
val_split = 0.1
hidden_dim = 5

num_runs = 1
n_epochs = 5000

# %%
params = {'n_series':data.shape[1], 'hidden_size':5, 'lr':1e-3, 'n_epochs':n_epochs, 'batch_size':batch_size, 'train_split':train_split, 'val_split':val_split, 'context_window':context_window, 'aggregate':False,
          'coherency_loss':True, 'profhit':False, 'coherency_weight':weight, 'project':False}
coherency_results, names, losses = repeat_exp(BaseModel, base_agg_mat, data, params, num_runs)
# Out:
# run 0
# 100%|██████████| 5000/5000 [01:00<00:00, 82.99it/s]

# %%
all_losses
# Out:
# [([1,
#    0.24009481072425842,
#    0.21518225967884064,
#    0.2170470803976059,
#    0.20688854157924652,
#    0.19397859275341034,
#    0.17886997759342194,
#    0.16590917110443115,
#    0.16237670183181763,
#    0.14377151429653168,
#    0.1369919776916504,
#    0.1279202699661255,
#    0.11847782880067825,
#    0.11648813635110855,
#    0.10945737361907959,
#    0.1076241284608841,
#    0.1009221225976944,
#    0.10154473036527634,
#    0.09759146720170975,
#    0.09709995985031128,
#    0.09784328937530518,
#    0.0872960165143013,
#    0.08389335125684738,
#    0.08408427238464355,
#    0.07924914360046387,
#    0.08156612515449524,
#    0.0771942213177681,
#    0.07508061826229095,
#    0.07065290957689285,
#    0.07083369046449661,
#    0.06980276107788086,
#    0.06837061792612076,
#    0.06676419824361801,
#    0.06570640951395035,
#    0.06351907551288605,
#    0.06339400261640549,
#    0.062251534312963486,
#    0.06059761345386505,
#    0.058414850383996964,
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np


# Create the figure and the first axis
fig, ax1 = plt.subplots(figsize=(10, 6))
ax2 = ax1.twinx()

cmap = cm.get_cmap('RdBu')  # Red to Blue colormap

for i, losses in enumerate(all_losses):

    color_val = 0 + i / (2*(len(all_losses) - 1))

    # Plot the training loss on the first y-axis
    color1 = 'tab:blue'
    # ax1.plot(losses[0], label='Training Loss', color=color1)
    ax1.set_xlabel('Epochs', fontsize=16)
    ax1.set_ylabel('MSE Loss', color=color1, fontsize=16)
    ax1.tick_params(axis='y', labelcolor=color1, labelsize=14)
    # ax1.plot([np.mean(losses[2][9*i//10:i]) for i in range(len(losses[2]))], label='validation loss', color=cmap(color_val))
    if i == 0: 
        color = 'purple'
        label = 'no coherency'
        alpha=0.8
    elif i >= len(all_losses)-1: 
        color='black'
        label='highest coherency weight (0.2)'
        alpha=0.8
    else: 
        color='green'
        label=None
        alpha=0.5
    ax1.plot([np.mean(losses[2][9*i//10:i]) for i in range(len(losses[2]))], label=label, color=color, alpha=alpha)

    # Create a second y-axis for coherency
#     # ax2 = ax1.twinx()
#     color2 = 'tab:red'
#     # ax2.plot(np.log(np.array(losses[1][1:])), label='Coherency', color=color2)
#     ax2.plot(np.array(losses[1][1:]), label='Coherency', color=color2)
#     ax2.set_ylabel('Coherency', color=color2, fontsize=16)
#     ax2.tick_params(axis='y', labelcolor=color2, labelsize=14)

#     # Add legends for both plots
fig.legend(loc='upper right', bbox_to_anchor=(0.475, 0.27), fontsize=14)

# Add a title and adjust layout
plt.title('Validation loss across coherency weights', fontsize=18)
ax1.set_ylim(0.2, 2)
fig.tight_layout()


plt.savefig('results/validation_vs_coherency_weights.png')
plt.show()
# Out:
# /tmp/ipykernel_67750/3105595885.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('RdBu')  # Red to Blue colormap

# %%
# Coherency loss

# coherency_params = np.exp(-np.arange(0, 0.2, 0.02))
coherency_params = np.arange(0, 0.2, 0.02)
print(coherency_params)
all_coherency_results = []
all_losses = []
for weight in coherency_params:
    params = {'n_series':data.shape[1], 'hidden_size':5, 'lr':1e-3, 'n_epochs':n_epochs, 'batch_size':64, 'train_split':train_split, 'val_split':val_split, 'context_window':context_window, 'aggregate':False,
              'coherency_loss':True, 'profhit':False, 'coherency_weight':weight, 'project':False}
    coherency_results, names, losses = repeat_exp(BaseModel, base_agg_mat, data, params, num_runs)
    all_losses.append(losses)
    all_coherency_results.append(coherency_results)
# Out:
# [0.   0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18]
# run 0
# 100%|██████████| 5000/5000 [01:01<00:00, 81.05it/s]
# run 0
# 100%|██████████| 5000/5000 [01:01<00:00, 80.97it/s]
# run 0
# 100%|██████████| 5000/5000 [01:00<00:00, 82.38it/s]
# run 0
# 100%|██████████| 5000/5000 [01:00<00:00, 82.49it/s]
# run 0
# 100%|██████████| 5000/5000 [01:00<00:00, 82.16it/s]
# run 0
# 100%|██████████| 5000/5000 [01:02<00:00, 79.61it/s]
# run 0
# 100%|██████████| 5000/5000 [01:01<00:00, 81.92it/s]
# run 0
# 100%|██████████| 5000/5000 [01:00<00:00, 83.29it/s]
# run 0
# 100%|██████████| 5000/5000 [00:59<00:00, 83.52it/s]
# run 0
# 100%|██████████| 5000/5000 [01:01<00:00, 81.01it/s]

# %%
# profhit loss

# all_profhit_results = []
for weight in coherency_params[1:]:
    params = {'n_series':data.shape[1], 'hidden_size':5, 'lr':1e-3, 'n_epochs':n_epochs, 'batch_size':64, 'train_split':train_split, 'val_split':val_split, 'context_window':context_window, 'aggregate':False,
              'coherency_loss':False, 'profhit':True, 'coherency_weight':weight, 'project':False}
    profhit_results, names, _ = repeat_exp(BaseModel, base_agg_mat, data, params, num_runs)
    all_profhit_results.append(profhit_results)
# Out:
# run 0
# 100%|██████████| 5000/5000 [00:59<00:00, 84.36it/s]
# run 0
# 100%|██████████| 5000/5000 [00:57<00:00, 86.39it/s]
# run 0
# 100%|██████████| 5000/5000 [00:57<00:00, 87.29it/s]
# run 0
# 100%|██████████| 5000/5000 [00:56<00:00, 87.87it/s]
# run 0
# 100%|██████████| 5000/5000 [00:59<00:00, 83.45it/s]
# run 0
# 100%|██████████| 5000/5000 [00:58<00:00, 86.15it/s]
# run 0
# 100%|██████████| 5000/5000 [00:57<00:00, 87.03it/s]
# run 0
# 100%|██████████| 5000/5000 [00:58<00:00, 85.39it/s]
# run 0
# 100%|██████████| 5000/5000 [00:57<00:00, 86.23it/s]

# %%
profhit_wmapes = []
profhit_coh = []
for r in all_profhit_results:
    avg_wmape = r.mean(axis=1).mean(axis=0)[2]
    avg_coh = r.mean(axis=1).mean(axis=0)[0]
    profhit_wmapes.append(avg_wmape)
    profhit_coh.append(avg_coh)

# %%
coh_wmapes = []
coherency_coh = []
for r in all_coherency_results:
    avg_wmape = r.mean(axis=1).mean(axis=0)[2]
    avg_coh = r.mean(axis=1).mean(axis=0)[0]
    coh_wmapes.append(avg_wmape)
    coherency_coh.append(avg_coh)

# %%
all_coherency_results = np.array(all_coherency_results)
all_coherency_results.shape
# Out:
# (10, 1, 4, 3)

# %%
# plt.plot(coherency_params, profhit_wmapes, label='profhit')
plt.plot(coherency_params, coh_wmapes, label='coherency loss')
plt.legend()

# %%
# plt.plot(coherency_params, profhit_coh, label='profhit')
plt.plot(coherency_params, coherency_coh, label='coherency loss')
plt.legend()
